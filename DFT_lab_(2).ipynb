# %% [markdown]
# <a href="https://colab.research.google.com/github/shpinatashan/List/blob/master/DFT_lab_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 Сигналы
#
# 16 - циклический сдвиг
#
# Все сигналы можно разделить на четыре группы:
#
# аналоговые,
#
# дискретные,
#
# квантованные,
#
# цифровые.
#
# **Аналоговый сигнал** – описывается непрерывной функцией времени. Аналоговый сигнал обеспечивает передачу данных путем непрерывного изменения во времени амплитуды, частоты или фазы. Практически все физические процессы описываются непрерывными функциями времени, поэтому представляют собой аналоговые сигналы. Для аналогового сигнала область значений и определения описывается непрерывным множеством.
#
# Для **дискретного сигнала** свойственно прерывистое (дискретное) изменение сигнала во времени. То есть изменения в сигнале происходят скачкообразно через некоторые промежутки времени, называемые интервалом дискретизации – Δt или Td. Дискретизация аналогового сигнала состоит в том, что сигнал представляется в виде последовательности значений, взятых в дискретные моменты времени, которые называются отсчётами (сэмплами).
#
# Для правильного восстановления аналогового сигнала из цифрового без искажений и потерь используется теорема отсчетов, известная как **теорема Котельникова (Найквиста-Шеннона)**.
#
# Любой непрерывный сигнал с ограниченным спектром может быть восстановлен однозначно и без потерь по своим дискретным отсчетам, взятым с частотой строго больше удвоенной верхней частоты спектра непрерывного сигнала.
#
# Формула теоремы Котельникова:
#
# Fs = 1\Ts > 2Fa, где
#
# Fs - частота дискретизации сигнала,
#
# Fa - верхняя частота спектра аналогового сигнала.
#
# Такое определение относится к функциям времени, которые состоят из частот от нуля до Fa.
#
# В реальных задачах в радиотехнике спектр сигнала может лежать в любом диапазоне частот и начинаться и заканчиваться на любой частоте, в связи с этим определение **теоремы Котельникова **правильно рассматривать относительно ширины спектра такого сигнала:
#
# Любой непрерывный сигнал с ограниченным спектром может быть восстановлен однозначно и без потерь по своим дискретным отсчетам, взятым с частотой строго больше удвоенной ширины полосы частот, занимаемой спектром непрерывного сигнала.
#
# Fs = 1\Ts > 2\Delta_f, где
#
# Delta_f - ширина спектра непрерывного сигнала.
#
# **Квантованные сигналы** принимают ряд конечных значений из диапазона непрерывных или дискретных величин. Как правило, сигналы квантуются по уровню, то есть по амплитуде.
#
# **Цифровые сигналы** получаются из **аналоговых** с помощью операций **дискретизации** и **квантования** по уровню. Значениям цифрового сигнала присваивается кодовое слово или набор символов (зачастую двоичных).
#
# Задание:
# 1) создать ряд временных значений: Функция np.linspace(start, stop, num) задает вектор в диапазоне [start, stop], а num - количество точек в диапазоне.
#
# 2)создать сигнал произвольной формы: С помощью функции np.sin() задаём сигнал из набора гармонических воздействий. Для простоты амплитуды всех компонент равны 1, а смещение по фазе нулевое.
#
# 3)Отрисовка графиков. Методы matplotlib задают различный стиль отображения:
# plot() - стандартный график, выводит сигнал в аналоговой форме,
# stem() - график в виде отсчетов, выводит сигнал в дискретной форме,
# step() - график в виде уровней, выводит сигнал в квантованной форме.

# %% [markdown]
# # Упражнение
#
# Если неверно выбраны шаг квантования и дискретизации, то преобразование сигнала из аналоговой формы в дискретную будет происходить с искажениями.
#
# Зададим график синуса. Допустим длина сигнала n = 64 отсчетов, на которых укладывается один период гармонического сигнала. Установим шаг квантования таким образом, чтобы d = 3, 5, 8 и 32 отсчетов

# %%
import numpy as np
import matplotlib.pyplot as plt
#YOUR CODE
n = 64
t = np.linspace(0, 1, n, endpoint=True)
step_lst = np.array([2, 8,32])
x = np.sin(1000*np.pi*t)
plt.title('Number of points = {}'.format(step_lst[0]))
plt.subplot(3,1,1)
plt.plot(t, x)
plt.subplot (3,1,2)
plt.stem(t, x)
plt.subplot (3,1,3)
plt.step(t, x)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if sys.path[0] == '':

# %%
n = 64
# time vector
t = np.linspace(0, 1, n, endpoint=True)
# signal
x = np.sin(2*np.pi*t)

# discrete step
step_lst = np.array([2, 8, 32])

#plot figure
fig = plt.figure(figsize=(12, 6), dpi=80)

tt = np.linspace(0, 1, step_lst[0], endpoint=True)
plt.subplot(3, 1, 1)
plt.title('Number of points = {}'.format(step_lst[0]))
plt.plot(t, x, '-', linewidth=2.0)
plt.plot(tt, np.sin(2*np.pi*tt), '--o', linewidth=1.5, markersize=8)
plt.step(tt, np.sin(2*np.pi*tt), linewidth=1.5)
plt.grid()
plt.xlim([0, 1])

tt = np.linspace(0, 1, step_lst[1], endpoint=True)
plt.subplot(3, 1, 2)
plt.title('Number of points = {}'.format(step_lst[1]))
plt.plot(t, x, '-', linewidth=2.0)
plt.plot(tt, np.sin(2*np.pi*tt), '--o', linewidth=1.5, markersize=8)
plt.step(tt, np.sin(2*np.pi*tt), linewidth=1.5)
plt.grid()
plt.xlim([0, 1])

tt = np.linspace(0, 1, step_lst[2], endpoint=True)
plt.subplot(3, 1, 3)
plt.title('Number of points = {}'.format(step_lst[2]))
plt.plot(t, x, '-', linewidth=2.0)
plt.plot(tt, np.sin(2*np.pi*tt), '--o', linewidth=1.5, markersize=8)
plt.step(tt, np.sin(2*np.pi*tt), linewidth=1.5)
plt.grid()
plt.xlim([0, 1])

plt.tight_layout()

# %% [markdown]
# # 1.2 Действительная и мнимые части сигнала.
# В результате применения функции fft получим комплексную составляющую спектра исходного сигнала, представленную в алгебраической форме. По составляющим вектора X можно  определить  модуль,  отдельно  действительную  и  отдельно  мнимую  составляющие спектра.
#
# Задание: разобраться как работает numpy.fft, разработать  скрипт  для  построения  графиков  анализируемого  сигнала, действительной  и  мнимой  составляющей  сигнала  и  график  модуля  гармоник и спектра фазы согласно вашему варианту.

# %%
N=25
dpi = 80                   #Количество отсчетов.
n=np.linspace(0,25,N)   #Индексы отсчетов.
Fd=1/8000              #Частота дискретизации.
x=np.sin(2*np.pi*1000*n*Fd) #Входной сигнал.


plt.figure(1)
plt.plot(x)            #График анализируемого сигнала.
plt.show()
y=np.fft.fft(x)        #Преобразование Фурье.   
plt.stem(np.abs(y))     #График амплитудного спектра. 
plt.show()
plt.stem(np.angle(y))   #График фазового спектра
plt.show()

plt.figure(2)              
plt.stem(y.real)
plt.show()
plt.figure(3)
plt.stem(y.imag)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %% [markdown]
# # 1.3 DFT своими руками
#
# Задание: написать функцию дискретного преобразования Фурье без использования numpy.fft. Показать, что она работает, применив ее к сигналу в предыдущем пункте. Вывести те же графики.

# %%
#YOUR CODE
def DFT(x):
    """Compute the discrete Fourier Transform of the 1D array x"""
    x = np.asarray(x, dtype=float)
    N = x.shape[0]
    n = np.arange(N)
    k = n.reshape((N, 1))
    M = np.exp(-2j * np.pi * k * n / N)
    return np.dot(M, x)


x = np.random.random(1024)
np.allclose(DFT(x), np.fft.fft(x))


N=25
dpi = 80                   #Количество отсчетов.
n=np.linspace(0,25,N)   #Индексы отсчетов.
Fd=1/8000              #Частота дискретизации.
x1=np.sin(2*np.pi*1000*n*Fd) #Входной сигнал.


plt.figure(1)
plt.plot(x1)            #График анализируемого сигнала.
plt.show()
y=DFT(x1)        #Преобразование Фурье.   
plt.stem(np.abs(y))     #График амплитудного спектра. 
plt.show()
plt.stem(np.angle(y))   #График фазового спектра
plt.show()

plt.figure(2)              
plt.stem(y.real)
plt.show()
plt.figure(3)
plt.stem(y.imag)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %% [markdown]
# # 1.3 Циклический сдвиг
#
# Задание: написать код так, что получить графики модуля и фазы ДПФ для последовательности, полученной из входной последовательности циклическим сдвигом. Сравнить графики с исходными и объяснить полученные результаты.

# %%
N=25                   #Количество отсчетов.
n=np.linspace(0,25,N)   #Индексы отсчетов.
Fd=1/8000   
a = 11           #Частота дискретизации.
x=np.sin(2*np.pi*1000*(n)*Fd) #Входной сигнал.
x_shifted=np.sin(2*np.pi*1000*(n-a)*Fd)
plt.figure()
plt.plot(x)            #График анализируемого сигнала.
plt.show()
y=np.fft.fft(x)        #Преобразование Фурье.   
plt.stem(np.abs(y))     #График амплитудного спектра. 
plt.show()
plt.stem(np.angle(y))   #График фазового спектра
plt.show()

#YOUR CODE
plt.figure()
plt.plot(x_shifted)            #График анализируемого сигнала.
plt.show()
y_shifted=np.fft.fft(x_shifted)        #Преобразование Фурье.   
plt.stem(np.abs(y_shifted))     #График амплитудного спектра. 
plt.show()
plt.stem(np.angle(y_shifted))   #График фазового спектра
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]
# ...

# %% [markdown]
# # 1.4 Частотная ось
#
# Задание: определить расстояние в Гц между соседними бинами. По спектру оценить частоты f1 и f2 сигнала состоящего из суммы двух синусоид с точностью до 1Гц. Проанализировать как на наблюдаемый спектр влияет частота дискретизации и время накопления сигнала.

# %%
Fd = 200
dt=1/Fd
RunToTime = 10
n = (RunToTime-dt)/dt
t=np.linspace(0,RunToTime-dt,(RunToTime-dt)/dt)
input_signal = np.sin(2*np.pi*7*n*t)+0.5*np.sin(2*np.pi*25*n*t+3*np.pi/4)
out_fft = np.fft.fft(input_signal)
plt.figure(figsize=(15, 10), dpi=80)
plt.subplot(6,2,1); plt.plot(t, input_signal)
plt.title('Input Singnal') 
plt.xlabel('t, s')
plt.ylabel('Vin')

plt.subplot(6,2,2) 
plt.stem(np.abs(out_fft))
plt.xlim([0, 2000])
plt.title('|DFT|')
plt.xlabel('n')


plt.subplot(6,2,5) 
plt.stem(np.abs(out_fft))
plt.xlim([50, 100])
plt.title('|DFT|')
plt.xlabel('n')

plt.subplot(6,2,6) 
plt.stem(np.abs(out_fft))
plt.xlim([200,300])
plt.title('|DFT|')
plt.xlabel('n')

N=(RunToTime-dt)/dt
print(250*Fd/N)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %% [markdown]
# # 1.5 ДПФ и ДВПФ
#
# Задание: Необходимо добавить нули к сигналу (padding) таким образом на последующем графике будет изображена огибающая, построенная по отсчетам ДПФ, аппроксимирующая вид ДВПФ для входного сигнала. Написать свой код процедуры добавления нулей.
#
# По спектру определить частоты сигнала. Проанализировать как на наблюдаемый график модуля ДВПФ влияет количество нулей, дописанных в конец входной последовательности. Сравнить полученные результаты исходного сигнала и сигнала с добавлением нулей.

# %%
Fd = 200
dt=1/Fd

RunToTime = 0.8
n = (RunToTime-dt)/dt
t=np.linspace(0,RunToTime-dt,(RunToTime-dt)/dt)
input_signal = np.sin(2*np.pi*7*n*t)+0.5*np.sin(2*np.pi*25*n*t+3*np.pi/4)

#YOUR CODE for padded time (to plot graph) and padded signal
#padding = int((RunToTime-dt)/dt)
padding = 200
padded_signal = np.pad(input_signal, (0, padding), 'constant', constant_values=(0))
padded_time = np.pad(t, (0, padding), 'constant', constant_values=(0))
#
out_fft = np.fft.fft(padded_signal)
df = Fd/padded_signal.shape[0]
out_f = np.linspace(0,Fd-df,(Fd)/df)

plt.figure(figsize=(12, 6), dpi=80)
plt.subplot(2,1,1); 
plt.plot(padded_time, padded_signal) 
plt.title('Input Singnal')
plt.xlabel('t, s')
plt.ylabel('Vin')
plt.subplot(2,1,2)
plt.xlim([75, 125])
plt.plot(out_f, abs(out_fft))
plt.title('|DFT|')
plt.xlabel('f, Hz')
# Out:
# Text(0.5, 0, 'f, Hz')

# %%
()
